# %% [markdown]
# # Importar Librerías

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import STL
from statsmodels.tsa.holtwinters import ExponentialSmoothing
from pmdarima import auto_arima
from scipy import stats

# %% [markdown]
# # Cargar los Datos

# %%
# URL del archivo en GitHub
url = "https://raw.githubusercontent.com/Carlos123456789012/Series_De_Tiempo/refs/heads/main/Tarea2/ozono.csv"

# Leer el archivo, omitiendo la primera fila y especificando los nombres de las columnas
df = pd.read_csv(url, sep=r'[ ,]+', skiprows=1, header=None, names=['Fecha', 'Hora', 'CO2(mg/m3)'], engine='python')

# Convertir las columnas 'Fecha' y 'Hora' en una sola columna 'FechaHora' de tipo datetime
df['FechaHora'] = pd.to_datetime(df['Fecha'] + ' ' + df['Hora'], format='%m/%d/%Y %H:%M')

# Establecer 'FechaHora' como el índice y eliminar las columnas 'Fecha' y 'Hora'
df.set_index('FechaHora', inplace=True)
df.drop(columns=['Fecha', 'Hora'], inplace=True)

# Verificar que se leyeron bien los datos
print(df.head())
# Out:
#                      CO2(mg/m3)
# FechaHora
# 2018-01-19 14:00:00        0.50
# 2018-01-19 15:00:00        0.46
# 2018-01-19 16:00:00        0.84
# 2018-01-19 17:00:00        0.95
# 2018-01-19 18:00:00        1.24

# %% [markdown]
# ## Interpolación de Datos Faltantes

# %% [markdown]
# ### Haremos una interpolación de los datos basada en el tiempo (`method='time'`)
#
# **Razones:**
#
# 1. **Series Temporales con Frecuencia Regular**:
#    Dado que los datos tienen una frecuencia fija (una medición cada hora), la interpolación basada en tiempo utiliza los intervalos horarios para ajustar los valores faltantes.
#
# 2. **Patrones Estacionales o Diurnos**:
#    Este método es especialmente útil si los valores faltantes están distribuidos en diferentes épocas del día o del año, ya que utiliza los intervalos de tiempo para realizar una interpolación más adecuada para series temporales.
#
# 3. **Adecuación a Intervalos Regulares**:
#    La interpolación basada en tiempo asegura que los valores interpolados se ajusten bien a intervalos regulares, que es lo que ideal en nuestro contexto de una serie de datos que se mide a intervalos constantes como cada hora.

# %%
df['CO2(mg/m3)'] = df['CO2(mg/m3)'].interpolate(method='time')

# Verificar que ya no haya datos nulos
print("Datos faltantes después de la interpolación:", df['CO2(mg/m3)'].isnull().sum())
# Out:
# Datos faltantes después de la interpolación: 0

# %% [markdown]
# # Análisis del 10% de datos de la Serie Temporal

# %% [markdown]
# ## Selección del 10% final de los Datos

# %%
ultimo_decil_df = df[-int(0.1 * len(df)):]

# Gráfico del 10% de la Serie Temporal

plt.figure(figsize=(20, 4))
plt.plot(ultimo_decil_df.index, ultimo_decil_df['CO2(mg/m3)'], label='CO2 (mg/m3)', color='blue')
plt.title('Serie Temporal de CO2 (mg/m3)')
plt.xlabel('Fecha')
plt.ylabel('CO2 (mg/m3)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Estacionariedad

# %% [markdown]
# ### Análisis de Estacionariedad con test de Dickey-Fuller Aumentado (ADF)

# %%
result = adfuller(ultimo_decil_df['CO2(mg/m3)'].dropna())
print("ADF Statistic:", result[0])
print("p-value:", result[1])

# Determinar si es necesario remover la estacionalidad
if result[1] > 0.05:
    print("La serie tiene raíces unitarias, ergo, NO es estacionaria.")
else:
    print("La serie no tiene raíces unitarias, ergo, es estacionaria.")
# Out:
# ADF Statistic: -6.954477644051031
# p-value: 9.506508077145249e-10
# La serie no tiene raíces unitarias, ergo, es estacionaria.

# %% [markdown]
# Dado que el **p-value** es muy bajo, podemos **rechazar la hipótesis nula** con un alto nivel de confianza. Esto significa que, según los resultados de la prueba ADF, **la serie es estacionaria** y no tiene una raíz unitaria.

# %% [markdown]
# ### Análisis de Estacionariedad SIN DIFERENCIAR la Serie

# %% [markdown]
# ### Análisis Estacionariedad a la **Serie Original** con ACF y PACF

# %%
# Graficar ACF y PACF del último 10% de la columna 'CO2(mg/m3)'
plt.figure(figsize=(20, 5))

# Gráfico de ACF
plt.subplot(1, 2, 1)
plot_acf(ultimo_decil_df['CO2(mg/m3)'], lags=20, ax=plt.gca())
plt.title('ACF del último 10% de los datos de CO2')

# Gráfico de PACF
plt.subplot(1, 2, 2)
plot_pacf(ultimo_decil_df['CO2(mg/m3)'], lags=20, ax=plt.gca(), method='ywm')
plt.title('PACF del último 10% de los datos de CO2')

plt.tight_layout()
plt.show()

# %% [markdown]
# Dado que comportamiento de decaimiento lento del ACF y PACF se sugiere que la serie podría ser no estacionaria y tener una dependencia a largo plazo entre cada paso.

# %% [markdown]
# ## Estacionalidad

# %% [markdown]
# Dado que la serie necesitaba una diferenciación por lo mencionado en ARIMA, para analizar la serie de una manera más adecuada, analizaremos la componente estacional a la `ultimo_decil_df['CO2(mg/m3)']`. Dado el comportamiento de la serie, nos inclinaremos por una decomposición aditiva de la serie.

# %%
# Realizar la descomposición aditiva
descomposicion_aditiva = seasonal_decompose(ultimo_decil_df['CO2(mg/m3)'], model='additive', period=24)  # Asumiendo estacionalidad diaria (1 ciclo completo es de 24 horas)

# Graficar la descomposición aditiva
fig, (ax1, ax2, ax3, ax4) = plt.subplots(4, 1, figsize=(20, 10))
fig.suptitle('Descomposición Aditiva de la Serie', fontsize=16)

# Graficar las componentes con títulos
descomposicion_aditiva.observed.plot(ax=ax1, legend=False)
ax1.set_title('Serie Observada')

descomposicion_aditiva.trend.plot(ax=ax2, legend=False)
ax2.set_title('Tendencia')

descomposicion_aditiva.seasonal.plot(ax=ax3, legend=False)
ax3.set_title('Estacionalidad')

descomposicion_aditiva.resid.plot(ax=ax4, legend=False)
ax4.set_title('Residuo')

plt.tight_layout(rect=[0, 0, 1, 0.95])
plt.show()

# %% [markdown]
# **Comentarios sobre Estacionalidad:**
#
# Podemos notar subidos peaks periodicos, sugiriendo que existe una componente de estacionalidad, por lo cual, será necesario quitar esta componente para un trabajo optimal con el modelo ARMA que es ineficiente con datos que presentan estacionalidad.

# %% [markdown]
# ### Suprimir la componente Estacional de la Serie

# %% [markdown]
# #### Método 1: Quitar estacionalidad de la forma **SerieOriginal-ComponenteEstacionalSerie**

# %%
# Quitar la estacionalidad restando el componente estacional a la serie original
serie_sin_estacionalidad = ultimo_decil_df['CO2(mg/m3)'] - descomposicion_aditiva.seasonal

# Graficar la serie sin estacionalidad
plt.figure(figsize=(20, 5))
plt.plot(serie_sin_estacionalidad, label='Serie sin Estacionalidad')
plt.title('Serie Temporal sin Estacionalidad')
plt.xlabel('FechaHora')
plt.ylabel('CO2(mg/m3)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### Método 2: Aplicar filtro MA a la Serie

# %%
# Aplicar un filtro de promedio móvil con periodicidad de 24 horas
serie_promedio_movil = ultimo_decil_df['CO2(mg/m3)'].rolling(window=12, center=True).mean()
# Eliminar valores NaN de la serie con promedio móvil
serie_promedio_movil = serie_promedio_movil.dropna()

# Graficar la serie original y la serie con promedio móvil
plt.figure(figsize=(20, 5))
plt.plot(ultimo_decil_df['CO2(mg/m3)'], label='Serie Diferenciada')
plt.plot(serie_promedio_movil, label='Serie con Promedio Móvil (12 horas)', color='orange')
plt.title('Serie Temporal con Promedio Móvil de 24 Horas')
plt.xlabel('FechaHora')
plt.ylabel('CO2(mg/m3)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Ajustar modelo **ARMA(p,q)**

# %% [markdown]
# ### Selección de Parámetros **(p,q)** mediante BIC y AIC.

# %%
# Aplicar auto_arima a la serie diferenciada para seleccionar los mejores parámetros p, d, q basados en AIC o BIC
modelo_auto_ultimo = auto_arima(
    serie_promedio_movil,  
    start_p=0, 
    start_q=0,
    max_p=5, 
    max_q=5, 
    seasonal=False,  
    trace=True,  # Muestra el proceso de selección
    information_criterion='bic',  # Usa BIC (o cambia a 'aic' si prefieres)
    stepwise=True  # Busca los mejores parámetros de manera más eficiente
)

# Mostrar el resumen del mejor modelo encontrado
#print(modelo_auto_ultimo.summary())
# Imprimir el mejor modelo con sus valores de BIC y AIC
mejor_modelo = modelo_auto_ultimo

print(f"El mejor modelo seleccionado es ARIMA({mejor_modelo.order}) con:")
print(f"AIC = {mejor_modelo.aic():.2f}")
print(f"BIC = {mejor_modelo.bic():.2f}")
# Out:
# Performing stepwise search to minimize bic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=-11151.650, Time=0.42 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=-15061.204, Time=0.30 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=-14691.664, Time=0.82 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=-11160.064, Time=0.24 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=-15619.192, Time=0.95 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=-16176.625, Time=0.78 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=-16201.976, Time=0.50 sec
#  ARIMA(5,1,0)(0,0,0)[0] intercept   : BIC=-16463.763, Time=0.60 sec
#  ARIMA(5,1,1)(0,0,0)[0] intercept   : BIC=-16818.994, Time=6.07 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=-16237.138, Time=5.28 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : BIC=-16275.101, Time=7.48 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : BIC=-16969.447, Time=6.54 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : BIC=-16931.265, Time=3.99 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : BIC=-17116.921, Time=3.77 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : BIC=-17031.987, Time=5.22 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : BIC=-17386.122, Time=6.19 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : BIC=-16667.402, Time=7.40 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : BIC=-16886.439, Time=6.40 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : BIC=-17501.988, Time=3.33 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : BIC=-17529.182, Time=2.97 sec
#  ARIMA(3,1,3)(0,0,0)[0]             : BIC=-17080.718, Time=2.73 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : BIC=-16915.414, Time=3.03 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : BIC=-17247.059, Time=3.55 sec
#  ARIMA(3,1,2)(0,0,0)[0]             : BIC=-16964.977, Time=2.10 sec
#  ARIMA(3,1,4)(0,0,0)[0]             : BIC=-16963.753, Time=3.15 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : BIC=-16300.736, Time=3.58 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : BIC=-16819.171, Time=4.50 sec
#
# Best model:  ARIMA(4,1,3)(0,0,0)[0]
# Total fit time: 91.920 seconds
# El mejor modelo seleccionado es ARIMA((4, 1, 3)) con:
# AIC = -17580.55
# BIC = -17529.18

# %% [markdown]
# ### Análisis ARIMA directo al último 10%

# %%
# Aplicar auto_arima a la serie original
modelo_auto_original = auto_arima(
    ultimo_decil_df['CO2(mg/m3)'],  # La serie original sin diferenciación manual
    start_p=0, 
    start_q=0,
    max_p=5, 
    max_q=5, 
    seasonal=False,  # Mantener estacionalidad desactivada si se ha desestacionalizado previamente
    trace=True,  # Muestra el proceso de selección
    information_criterion='bic',  # Usa BIC (o cambia a 'aic' si prefieres)
    stepwise=True  # Busca los mejores parámetros de manera más eficiente
)

# Mostrar el resumen del mejor modelo encontrado
print("Modelo ajustado a la serie original:")
print(modelo_auto_original.summary())

# Imprimir el mejor modelo con AIC y BIC
mejor_modelo = modelo_auto_original
print(f"El mejor modelo seleccionado es ARIMA({mejor_modelo.order}) con:")
print(f"AIC = {mejor_modelo.aic():.2f}")
print(f"BIC = {mejor_modelo.bic():.2f}")
# Out:
# Performing stepwise search to minimize bic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=4002.842, Time=0.34 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=3897.065, Time=0.29 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=3767.088, Time=0.41 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=3994.419, Time=0.26 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : BIC=3705.207, Time=0.77 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : BIC=3203.397, Time=1.04 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : BIC=3295.617, Time=0.30 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : BIC=3166.141, Time=1.13 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : BIC=3160.622, Time=0.47 sec
#  ARIMA(4,1,0)(0,0,0)[0] intercept   : BIC=3162.046, Time=0.69 sec
#  ARIMA(4,1,1)(0,0,0)[0] intercept   : BIC=3164.445, Time=2.13 sec
#  ARIMA(3,1,0)(0,0,0)[0]             : BIC=3152.199, Time=0.24 sec
#  ARIMA(2,1,0)(0,0,0)[0]             : BIC=3287.194, Time=0.17 sec
#  ARIMA(4,1,0)(0,0,0)[0]             : BIC=3153.623, Time=0.33 sec
#  ARIMA(3,1,1)(0,0,0)[0]             : BIC=3157.718, Time=0.63 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : BIC=3194.974, Time=0.45 sec
#  ARIMA(4,1,1)(0,0,0)[0]             : BIC=3156.022, Time=0.99 sec
#
# Best model:  ARIMA(3,1,0)(0,0,0)[0]
# Total fit time: 10.673 seconds
# Modelo ajustado a la serie original:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4553
# Model:               SARIMAX(3, 1, 0)   Log Likelihood               -1559.253
# Date:                Wed, 06 Nov 2024   AIC                           3126.506
# Time:                        23:23:16   BIC                           3152.199
# Sample:                    09-23-2022   HQIC                          3135.554
#                          - 03-31-2023
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1507      0.011     13.691      0.000       0.129       0.172
# ar.L2         -0.3165      0.011    -29.428      0.000      -0.338      -0.295
# ar.L3         -0.1761      0.011    -15.407      0.000      -0.199      -0.154
# sigma2         0.1161      0.002     73.004      0.000       0.113       0.119
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.22   Jarque-Bera (JB):              1884.46
# Prob(Q):                              0.64   Prob(JB):                         0.00
# Heteroskedasticity (H):               2.12   Skew:                            -0.36
# Prob(H) (two-sided):                  0.00   Kurtosis:                         6.07
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# El mejor modelo seleccionado es ARIMA((3, 1, 0)) con:
# AIC = 3126.51
# BIC = 3152.20

# %% [markdown]
# # Análisis del Penúltimo 10%

# %%
# Paso 1: Extraer el penúltimo 10% de la serie
df_penultimo_decil = df[-int(0.2 * len(df)):-int(0.1 * len(df))]

# Aplicar un filtro de promedio móvil para observar la estacionalidad
serie_promedio_movil_penultimo = df_penultimo_decil['CO2(mg/m3)'].rolling(window=12, center=True).mean()

# Eliminar los valores NaN que resulten del promedio móvil
serie_promedio_movil_penultimo = serie_promedio_movil_penultimo.dropna()

# Graficar la serie diferenciada y el promedio móvil
plt.figure(figsize=(14, 6))
plt.plot(df_penultimo_decil['CO2(mg/m3)'], label='Serie Observada')
plt.plot(serie_promedio_movil_penultimo, label='Promedio Móvil de la Serie', color='orange')
plt.title('Serie Temporal del Penúltimo 10% con Promedio Móvil')
plt.xlabel('Fecha')
plt.ylabel('CO2 (mg/m3)')
plt.legend()
plt.grid()
plt.show()

# Paso 3: Ajustar un modelo ARMA(p, q) usando auto_arima y justificar los parámetros
from pmdarima import auto_arima

modelo_auto_penultimo = auto_arima(
    serie_promedio_movil_penultimo,
    start_p=0,
    start_q=0,
    max_p=5,
    max_q=5,
    seasonal=False,
    trace=True,
    information_criterion='bic',
    stepwise=True
)

# Imprimir el resumen del modelo
print("Modelo ajustado al penúltimo 10% de la serie:")
print(modelo_auto_penultimo.summary())

# Imprimir los parámetros y criterios de AIC y BIC
print(f"El mejor modelo seleccionado es ARIMA({modelo_auto_penultimo.order}) con:")
print(f"AIC = {modelo_auto_penultimo.aic():.2f}")
print(f"BIC = {modelo_auto_penultimo.bic():.2f}")

# Paso 4: Realizar un test de raíces unitarias (Dickey-Fuller)
from statsmodels.tsa.stattools import adfuller

resultado_adf = adfuller(df_penultimo_decil['CO2(mg/m3)'].dropna())
print('\nResultados de la prueba Dickey-Fuller:')
print(f"Estadístico ADF: {resultado_adf[0]:.2f}")
print(f"p-valor: {resultado_adf[1]:.4f}")
if resultado_adf[1] <= 0.05:
    print("La serie es estacionaria (rechazamos la hipótesis nula).")
else:
    print("La serie no es estacionaria (no podemos rechazar la hipótesis nula). Se recomienda una diferenciación.")
# Out:
# Performing stepwise search to minimize bic
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : BIC=-13781.614, Time=0.34 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : BIC=-15527.352, Time=0.31 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : BIC=-16431.590, Time=1.17 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : BIC=-13790.035, Time=0.08 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : BIC=inf, Time=1.02 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : BIC=-17066.131, Time=1.75 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : BIC=-17063.712, Time=2.63 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : BIC=-17074.222, Time=2.12 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : BIC=-17089.313, Time=4.25 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : BIC=-18271.478, Time=4.72 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : BIC=-17497.399, Time=3.77 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : BIC=-19280.110, Time=5.89 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : BIC=-19079.092, Time=6.08 sec
#  ARIMA(4,1,3)(0,0,0)[0] intercept   : BIC=-19339.875, Time=5.89 sec
#  ARIMA(4,1,2)(0,0,0)[0] intercept   : BIC=-19338.220, Time=6.31 sec
#  ARIMA(5,1,3)(0,0,0)[0] intercept   : BIC=-19604.589, Time=8.07 sec
#  ARIMA(5,1,2)(0,0,0)[0] intercept   : BIC=-18198.858, Time=8.20 sec
#  ARIMA(5,1,4)(0,0,0)[0] intercept   : BIC=-18954.240, Time=9.56 sec
#  ARIMA(4,1,4)(0,0,0)[0] intercept   : BIC=-19254.650, Time=9.52 sec
#  ARIMA(5,1,3)(0,0,0)[0]             : BIC=-20070.045, Time=5.00 sec
#  ARIMA(4,1,3)(0,0,0)[0]             : BIC=-19414.559, Time=3.99 sec
#  ARIMA(5,1,2)(0,0,0)[0]             : BIC=-18194.390, Time=4.76 sec
#  ARIMA(5,1,4)(0,0,0)[0]             : BIC=-18996.487, Time=5.55 sec
#  ARIMA(4,1,2)(0,0,0)[0]             : BIC=-19358.345, Time=4.12 sec
#  ARIMA(4,1,4)(0,0,0)[0]             : BIC=-19273.289, Time=4.97 sec
#
# Best model:  ARIMA(5,1,3)(0,0,0)[0]
# Total fit time: 110.070 seconds
# Modelo ajustado al penúltimo 10% de la serie:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 4543
# Model:               SARIMAX(5, 1, 3)   Log Likelihood               10072.918
# Date:                Wed, 06 Nov 2024   AIC                         -20127.835
# Time:                        23:25:46   BIC                         -20070.045
# Sample:                    03-17-2022   HQIC                        -20107.482
#                          - 09-23-2022
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.2230      0.010    212.625      0.000       2.203       2.244
# ar.L2         -2.5055      0.026    -97.274      0.000      -2.556      -2.455
# ar.L3          1.8321      0.031     58.613      0.000       1.771       1.893
# ar.L4         -0.5260      0.025    -20.906      0.000      -0.575      -0.477
# ar.L5         -0.1295      0.012    -11.108      0.000      -0.152      -0.107
# ma.L1         -1.5462      0.011   -138.406      0.000      -1.568      -1.524
# ma.L2          1.2978      0.017     77.028      0.000       1.265       1.331
# ma.L3         -0.7130      0.010    -74.520      0.000      -0.732      -0.694
# sigma2         0.0007   3.59e-06    192.888      0.000       0.001       0.001
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.11   Jarque-Bera (JB):            633319.62
# Prob(Q):                              0.74   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.06   Skew:                             0.55
# Prob(H) (two-sided):                  0.27   Kurtosis:                        60.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# El mejor modelo seleccionado es ARIMA((5, 1, 3)) con:
# AIC = -20127.84
# BIC = -20070.05
#
# Resultados de la prueba Dickey-Fuller:
# Estadístico ADF: -5.35
# p-valor: 0.0000
# La serie es estacionaria (rechazamos la hipótesis nula).

# %% [markdown]
# # Pregunta 5

# %%
# Comparar los modelos ajustados al penúltimo y último 10% de la serie
print("Comparación de los modelos ajustados:")
print(f"Modelo del penúltimo 10%: ARIMA({modelo_auto_penultimo.order}) con AIC = {modelo_auto_penultimo.aic():.2f} y BIC = {modelo_auto_penultimo.bic():.2f}")
print(f"Modelo del último 10%: ARIMA({modelo_auto_ultimo.order}) con AIC = {modelo_auto_ultimo.aic():.2f} y BIC = {modelo_auto_ultimo.bic():.2f}")

# Extraer los coeficientes de los modelos
coef_penultimo = modelo_auto_penultimo.params().dropna()
coef_ultimo = modelo_auto_ultimo.params().dropna()

# Prueba de igualdad de medias para los coeficientes de los modelos
print("\nPrueba de igualdad de medias para los coeficientes de los modelos:")
for param in coef_penultimo.index:
    if param in coef_ultimo.index:
        mean1 = coef_penultimo[param]
        mean2 = coef_ultimo[param]
        
        # Verificar si los coeficientes son comparables
        if mean1 != 0 and mean2 != 0:
            # Calcular la diferencia absoluta entre los coeficientes
            diff = abs(mean1 - mean2)
            print(f"\nParámetro {param}:")
            print(f"Coeficiente del penúltimo 10%: {mean1:.4f}, coeficiente del último 10%: {mean2:.4f}")
            print(f"Diferencia absoluta: {diff:.4f}")
            
            # Verificar si la diferencia es significativa (umbral arbitrario de ejemplo)
            if diff > 0.01:  # Cambia el umbral según tu criterio
                print("Diferencia significativa en el parámetro entre los dos segmentos.")
            else:
                print("No hay diferencia significativa en el parámetro entre los dos segmentos.")
        else:
            print(f"\nParámetro {param}: No se comparó debido a valores cero o NaN.")
# Out:
# Comparación de los modelos ajustados:
# Modelo del penúltimo 10%: ARIMA((5, 1, 3)) con AIC = -20127.84 y BIC = -20070.05
# Modelo del último 10%: ARIMA((4, 1, 3)) con AIC = -17580.55 y BIC = -17529.18
#
# Prueba de igualdad de medias para los coeficientes de los modelos:
#
# Parámetro ar.L1:
# Coeficiente del penúltimo 10%: 2.2230, coeficiente del último 10%: 2.4364
# Diferencia absoluta: 0.2133
# Diferencia significativa en el parámetro entre los dos segmentos.
#
# Parámetro ar.L2:
# Coeficiente del penúltimo 10%: -2.5055, coeficiente del último 10%: -2.9025
# Diferencia absoluta: 0.3969
# Diferencia significativa en el parámetro entre los dos segmentos.
#
# Parámetro ar.L3:
# Coeficiente del penúltimo 10%: 1.8321, coeficiente del último 10%: 2.3041
# Diferencia absoluta: 0.4720
# Diferencia significativa en el parámetro entre los dos segmentos.
#
# Parámetro ar.L4:
# Coeficiente del penúltimo 10%: -0.5260, coeficiente del último 10%: -0.9011
# Diferencia absoluta: 0.3751
# Diferencia significativa en el parámetro entre los dos segmentos.
#
# Parámetro ma.L1:
# Coeficiente del penúltimo 10%: -1.5462, coeficiente del último 10%: -1.4889
# Diferencia absoluta: 0.0572
# Diferencia significativa en el parámetro entre los dos segmentos.
#
# Parámetro ma.L2:
# Coeficiente del penúltimo 10%: 1.2978, coeficiente del último 10%: 1.2156
# Diferencia absoluta: 0.0822
# Diferencia significativa en el parámetro entre los dos segmentos.
#
# Parámetro ma.L3:
# Coeficiente del penúltimo 10%: -0.7130, coeficiente del último 10%: -0.7089
# Diferencia absoluta: 0.0041
# No hay diferencia significativa en el parámetro entre los dos segmentos.
#
# Parámetro sigma2:
# Coeficiente del penúltimo 10%: 0.0007, coeficiente del último 10%: 0.0012
# Diferencia absoluta: 0.0005
# No hay diferencia significativa en el parámetro entre los dos segmentos.
